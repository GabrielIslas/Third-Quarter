# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('emision_mundial_de_co2_por_combustibles_fosiles.csv')

# %%
data
# Out:
#      AÑO         LOCALIZACION  EMISIONES_DE_CO2_(MILLONES_DE_TONELADAS)
# 0   1971               Mexico                                     93.70
# 1   1972               Mexico                                    106.42
# 2   1973               Mexico                                    117.60
# 3   1974               Mexico                                    128.25
# 4   1975               Mexico                                    134.60
# ..   ...                  ...                                       ...
# 89  2013  Resto de los paises                                  32129.37
# 90  2014  Resto de los paises                                  32381.04
# 91  2015  Resto de los paises                                  31833.60
# 92  2016  Resto de los paises                                  31868.70
# 93  2017  Resto de los paises                                  32106.80
#
# [94 rows x 3 columns]

# %%
data = data.drop(data[data.LOCALIZACION == 'Resto de los paises'].index)

# %%
data
# Out:
#      AÑO LOCALIZACION  EMISIONES_DE_CO2_(MILLONES_DE_TONELADAS)
# 0   1971       Mexico                                     93.70
# 1   1972       Mexico                                    106.42
# 2   1973       Mexico                                    117.60
# 3   1974       Mexico                                    128.25
# 4   1975       Mexico                                    134.60
# 5   1976       Mexico                                    145.16
# 6   1977       Mexico                                    154.26
# 7   1978       Mexico                                    170.15
# 8   1979       Mexico                                    183.77
# 9   1980       Mexico                                    204.60
# 10  1981       Mexico                                    219.48
# 11  1982       Mexico                                    230.30
# 12  1983       Mexico                                    223.77
# 13  1984       Mexico                                    231.77
# ...

# %%
data['EMISIONES_DE_CO2_(MILLONES_DE_TONELADAS)'].describe()
# Out:
# count     47.000000
# mean     300.522128
# std      111.142376
# min       93.700000
# 25%      227.035000
# 50%      291.300000
# 75%      417.800000
# max      457.640000
# Name: EMISIONES_DE_CO2_(MILLONES_DE_TONELADAS), dtype: float64

# %%
plt.plot(data['AÑO'], data['EMISIONES_DE_CO2_(MILLONES_DE_TONELADAS)'], 'r*-')

# %%
plt.streamplot(data['AÑO'], data['EMISIONES_DE_CO2_(MILLONES_DE_TONELADAS)'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 plt.streamplot(data['AÑO'], data['EMISIONES_DE_CO2_(MILLONES_DE_TONELADAS)'])
#
# TypeError: streamplot() missing 2 required positional arguments: 'u' and 'v'
