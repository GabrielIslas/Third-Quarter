# %%
import pandas as pd

# %%
df = pd.read_csv("data2.csv")
df
# Out:
#     PHP  Algoritmos  Bases  Programacion
# 0    13          15     15            13
# 1    13          14     13            12
# 2    13          16     13            14
# 3    15          20     14            16
# 4    16          18     18            17
# 5    15          16     17            15
# 6    12          13     15            11
# 7    13          16     14            15
# 8    13          15     14            13
# 9    13          14     13            10
# 10   11          12     12            10
# 11   14          16     11            14
# 12   15          17     16            15
# 13   15          19     14            16
# 14   15          13     15            10

# %%
df.describe()
# Out:
#              PHP  Algoritmos      Bases  Programacion
# count  15.000000   15.000000  15.000000     15.000000
# mean   13.733333   15.600000  14.266667     13.400000
# std     1.387015    2.261479   1.830951      2.354327
# min    11.000000   12.000000  11.000000     10.000000
# 25%    13.000000   14.000000  13.000000     11.500000
# 50%    13.000000   16.000000  14.000000     14.000000
# 75%    15.000000   16.500000  15.000000     15.000000
# max    16.000000   20.000000  18.000000     17.000000

# %%
df.corr()
# Out:
#                    PHP  Algoritmos     Bases  Programacion
# PHP           1.000000    0.715036  0.592530      0.669338
# Algoritmos    0.715036    1.000000  0.286359      0.917632
# Bases         0.592530    0.286359  1.000000      0.420884
# Programacion  0.669338    0.917632  0.420884      1.000000

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>
